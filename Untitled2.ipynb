# %% [markdown]
# <a href="https://colab.research.google.com/github/eysaritas/Diabetes-Prediction-System-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. KURULUM VE KÜTÜPHANELER ---
# !pip install cvzone

import cv2
import cvzone
import numpy as np
from google.colab.patches import cv2_imshow
import os

# --- 2. AYARLAR VE FONKSİYONLAR ---

path = 'ornek4.jpeg'

if not os.path.exists(path):
    print(f"HATA: '{path}' dosyası bulunamadı! Lütfen sol menüdeki klasör simgesine tıklayıp fotoğrafı yükleyin.")
else:
    # Resmi oku ve standart boyuta getir (640px genişlik)
    img_original = cv2.imread(path)
    base_width = 640
    ratio = base_width / img_original.shape[1]
    dim = (base_width, int(img_original.shape[0] * ratio))
    img = cv2.resize(img_original, dim, interpolation=cv2.INTER_AREA)

    def preProcessing(img):
        imgPre = cv2.GaussianBlur(img, (5, 5), 3)
        thresh1 = 50
        thresh2 = 150
        imgPre = cv2.Canny(imgPre, thresh1, thresh2)
        kernel = np.ones((3, 3), np.uint8)
        imgPre = cv2.dilate(imgPre, kernel, iterations=2)
        imgPre = cv2.morphologyEx(imgPre, cv2.MORPH_CLOSE, kernel)
        return imgPre

    def getColorCategory(imgCrop):
        """
        Paranın rengini analiz eder: Gümüş, Bakır veya Sarı
        HSV değerleri bu resim için optimize edilmiştir.
        """
        imgHSV = cv2.cvtColor(imgCrop, cv2.COLOR_BGR2HSV)
        h, w, _ = imgHSV.shape
        center_region = imgHSV[int(h/4):int(h*3/4), int(w/4):int(w*3/4)]

        avg_color_per_row = np.average(center_region, axis=0)
        avg_color = np.average(avg_color_per_row, axis=0)

        hue = avg_color[0]
        saturation = avg_color[1]

        # --- GÜNCELLENMİŞ RENK MANTIĞI ---
        # Gümüş (25 Kr): Doygunluk biraz daha yüksek olabilir ama Hue genelde nötrdür.
        # Eşiği 60'a çıkardık.
        if saturation < 60:
            return "gumus"

        # Bakır (1 Kr): Kırmızıya çok yakın tonlar ve yüksek doygunluk
        if (hue < 20 or hue > 160) and saturation > 50:
            return "bakir"

        # Diğerleri (Sarı - 1TL, 50Kr, 10Kr, 5Kr)
        return "sari"

    # --- 3. ANA İŞLEM ---

    imgPre = preProcessing(img)
    # Küçük gürültüleri almamak için minArea'yı artırdık.
    imgContours, conFound = cvzone.findContours(img, imgPre, minArea=1500)

    totalMoney = 0.0

    if conFound:
        print(f"{'-'*45}")
        print(f"{'PARA TİPİ':<10} | {'ALAN (AREA)':<15} | {'RENK'}")
        print(f"{'-'*45}")

        for count, contour in enumerate(conFound):
            area = contour['area']
            x, y, w, h = contour['bbox']

            imgCrop = img[y:y + h, x:x + w]
            colorType = getColorCategory(imgCrop)

            currentVal = 0.0
            label = ""
            color_box = (0, 255, 0) # Varsayılan Yeşil

            # --- GÜNCELLENMİŞ SINIFLANDIRMA MANTIĞI ---
            # 640px genişlikteki resim baz alınarak alanlar kalibre edildi.

            if colorType == "gumus":
                currentVal = 0.25
                label = "25 Kr"
                color_box = (255, 0, 0) # Mavi

            elif colorType == "bakir":
                currentVal = 0.01
                label = "1 Kr"
                color_box = (0, 165, 255) # Turuncu

            else: # SARI PARALAR (Boyuta göre kesin ayrım)
                # Bu alan değerleri gönderdiğin resimdeki paraların
                # 640px'e oranlanmış hallerine göre ayarlandı.
                if area > 6200:
                    currentVal = 1.0
                    label = "1 TL"
                elif 5000 < area <= 6200:
                    currentVal = 0.50
                    label = "50 Kr"
                elif 4000 < area <= 5000:
                    currentVal = 0.10
                    label = "10 Kr"
                elif 2000 < area <= 4000:
                    currentVal = 0.05
                    label = "5 Kr"
                else:
                    label = "Bilinmiyor" # Çok küçük sarı nesne

            if currentVal > 0:
                totalMoney += currentVal

            # Ekrana Çizdir
            cvzone.putTextRect(img, label, (x, y - 10), scale=1.5, thickness=2, offset=5, colorR=color_box)
            cv2.rectangle(img, (x, y), (x + w, y + h), color_box, 2)

            print(f"{label:<10} | {int(area):<15} | {colorType}")

    # --- 4. SONUÇLARI GÖSTERME ---
    print(f"{'-'*45}")
    print(f"TOPLAM PARA: {totalMoney:.2f} TL")

    # Ekrana sonucu yaz
    cvzone.putTextRect(img, f'Toplam: {totalMoney:.2f} TL', (20, 50), scale=2, thickness=2, colorR=(0,0,255))

    # Colab'da sonucu göster
    cv2_imshow(img)
# Out:
# Requirement already satisfied: cvzone in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from cvzone) (4.12.0.88)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cvzone) (2.0.2)
# ---------------------------------------------
# PARA TİPİ  | ALAN (AREA)     | RENK
# ---------------------------------------------
# 1 TL       | 17446           | sari
# 25 Kr      | 16920           | gumus
# 1 TL       | 11275           | sari
# 1 TL       | 10922           | sari
# ---------------------------------------------
# TOPLAM PARA: 3.25 TL
# <PIL.Image.Image image mode=RGB size=640x1137>

# %%
import cv2
import numpy as np
import os
import glob
from google.colab.patches import cv2_imshow

# --- AYARLAR ---
TEST_IMAGE = "1.jpeg"  # Test etmek istediğiniz görüntü

# Referansların bulunduğu dizin (Colab'de genelde '.' yani mevcut dizindir)
REF_DIR = "."

def get_sift_features(img_bgr):
    """Görüntüden SIFT özelliklerini çıkarır."""
    if img_bgr is None: return None, None
    sift = cv2.SIFT_create()
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    keypoints, descriptors = sift.detectAndCompute(gray, None)
    return keypoints, descriptors

def preProcessing(img):
    """Paraların yerini bulmak için ön işleme"""
    imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    imgBlur = cv2.GaussianBlur(imgGray, (5, 5), 3)

    # Eşik değerlerini biraz daha genel hale getirdik
    imgCanny = cv2.Canny(imgBlur, 30, 150)

    kernel = np.ones((3, 3), np.uint8)
    imgDilate = cv2.dilate(imgCanny, kernel, iterations=2)
    imgClosed = cv2.morphologyEx(imgDilate, cv2.MORPH_CLOSE, kernel)
    return imgClosed

def parse_value_from_filename(filename):
    """Dosya ismine bakarak paranın değerini anlar."""
    name = filename.lower()
    if "1tl" in name: return 1.00
    if "50kr" in name or "50krs" in name: return 0.50
    if "25kr" in name or "25krs" in name: return 0.25
    if "10kr" in name or "10krs" in name: return 0.10
    if "5kr" in name or "5krs" in name: return 0.05
    if "1kr" in name or "1krs" in name: return 0.01
    return 0.0

def main():
    # 1. TÜM REFERANS DOSYALARINI OTOMATİK BUL VE YÜKLE
    print("Referans havuzu taranıyor...")
    reference_data = []

    # jpg ve png dosyalarına bak
    files = [f for f in os.listdir(REF_DIR) if f.startswith("ref_") and (f.endswith(".jpg") or f.endswith(".png"))]

    for f in files:
        val = parse_value_from_filename(f)
        if val > 0:
            path = os.path.join(REF_DIR, f)
            img = cv2.imread(path)
            kp, des = get_sift_features(img)
            if des is not None:
                reference_data.append({
                    "name": f,
                    "value": val,
                    "kp": kp,
                    "des": des
                })
                print(f"-> Eklendi: {f} (Değer: {val} TL, Özellik: {len(kp)})")

    if not reference_data:
        print("HATA: 'ref_' ile başlayan hiç dosya bulunamadı! Lütfen dosyaları yükleyin.")
        return
    else:
        print(f"Toplam {len(reference_data)} adet referans şablonu yüklendi.")

    # 2. HEDEF GÖRÜNTÜYÜ AÇ
    img = cv2.imread(TEST_IMAGE)
    if img is None:
        print(f"Hedef resim ({TEST_IMAGE}) bulunamadı.")
        return

    imgDisplay = img.copy()
    imgPre = preProcessing(img)

    # 3. GÖRÜNTÜDEKİ PARALARI BUL
    contours, _ = cv2.findContours(imgPre, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    total_money = 0.0
    bf = cv2.BFMatcher()

    print(f"\nResimde {len(contours)} adet olası para bulundu. Analiz ediliyor...")

    for i, cnt in enumerate(contours):
        area = cv2.contourArea(cnt)

        if area > 800: # Alan filtresi
            x, y, w, h = cv2.boundingRect(cnt)
            imgCrop = img[y:y+h, x:x+w]

            kp_crop, des_crop = get_sift_features(imgCrop)

            if des_crop is None or len(kp_crop) < 5:
                continue

            best_match_val = 0
            max_good_matches = 0
            best_ref_name = ""

            # 4. HAVUZDAKİ TÜM REFERANSLARLA TEK TEK KIYASLA
            # Bu parayı elimizdeki BÜTÜN 1 TL, 50 Krş vb. fotoğraflarıyla karşılaştırıyoruz.
            # Hangisine en çok benziyorsa o kabul edilecek.
            for ref in reference_data:
                matches = bf.knnMatch(des_crop, ref["des"], k=2)

                good_matches = []
                for m, n in matches:
                    if m.distance < 0.75 * n.distance:
                        good_matches.append(m)

                if len(good_matches) > max_good_matches:
                    max_good_matches = len(good_matches)
                    best_match_val = ref["value"]
                    best_ref_name = ref["name"]

            # Eşik Değeri
            # Çoklu referansta en iyi eşleşmeyi bulacağımız için eşik değerini
            # biraz güvenli tutabiliriz (10-12 arası idealdir).
            if max_good_matches >= 10:
                total_money += best_match_val

                # Çizim
                cv2.rectangle(imgDisplay, (x, y), (x+w, y+h), (0, 255, 0), 2)

                if best_match_val < 1:
                    label = f"{int(best_match_val*100)} Kr"
                else:
                    label = f"{int(best_match_val)} TL"

                cv2.putText(imgDisplay, label, (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2)
                print(f"Para #{i+1}: {label} tespit edildi. (Referans: {best_ref_name}, Eşleşme: {max_good_matches})")
            else:
                # Tanınmayan nesne
                cv2.rectangle(imgDisplay, (x, y), (x+w, y+h), (0, 0, 255), 2)
                print(f"Para #{i+1}: Tanınamadı. (En yüksek eşleşme: {max_good_matches})")

    # SONUÇ GÖSTERİMİ
    print(f"\n--- TOPLAM TUTAR: {total_money:.2f} TL ---")

    cv2.putText(imgDisplay, f"TOPLAM: {total_money:.2f} TL", (20, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 4)

    print("Sonuç Görseli:")
    cv2_imshow(imgDisplay)

if __name__ == "__main__":
    main()
# Out:
# Referans havuzu taranıyor...
# -> Eklendi: ref_50kr_c.jpg (Değer: 0.5 TL, Özellik: 706)
# -> Eklendi: ref_1tl_d.jpg (Değer: 1.0 TL, Özellik: 704)
# -> Eklendi: ref_1kr_d.jpg (Değer: 0.01 TL, Özellik: 292)
# -> Eklendi: ref_1kr_b.jpg (Değer: 0.01 TL, Özellik: 517)
# -> Eklendi: ref_1tl_f.jpg (Değer: 1.0 TL, Özellik: 1343)
# -> Eklendi: ref_5kr_a.jpg (Değer: 0.05 TL, Özellik: 558)
# -> Eklendi: ref_1tl_h.jpg (Değer: 1.0 TL, Özellik: 1698)
# -> Eklendi: ref_1kr_g.jpg (Değer: 0.01 TL, Özellik: 359)
# -> Eklendi: ref_25kr_i.jpg (Değer: 0.25 TL, Özellik: 1305)
# -> Eklendi: ref_1tl_g.jpg (Değer: 1.0 TL, Özellik: 2402)
# -> Eklendi: ref_10kr_e.jpg (Değer: 0.1 TL, Özellik: 418)
# -> Eklendi: ref_25kr_c.jpg (Değer: 0.25 TL, Özellik: 635)
# -> Eklendi: ref_1kr_c.jpg (Değer: 0.01 TL, Özellik: 187)
# -> Eklendi: ref_10kr_d.jpg (Değer: 0.1 TL, Özellik: 499)
# -> Eklendi: ref_25kr_b.jpg (Değer: 0.25 TL, Özellik: 1038)
# -> Eklendi: ref_25kr_g.jpg (Değer: 0.25 TL, Özellik: 1290)
# -> Eklendi: ref_10kr_a.jpg (Değer: 0.1 TL, Özellik: 969)
# -> Eklendi: ref_1kr_a.jpg (Değer: 0.01 TL, Özellik: 1185)
# -> Eklendi: ref_10kr_c.jpg (Değer: 0.1 TL, Özellik: 250)
# -> Eklendi: ref_50kr_i.jpg (Değer: 0.5 TL, Özellik: 702)
# -> Eklendi: ref_1kr_e.jpg (Değer: 0.01 TL, Özellik: 860)
# -> Eklendi: ref_1tl_b.jpg (Değer: 1.0 TL, Özellik: 1051)
# -> Eklendi: ref_10kr_b.jpg (Değer: 0.1 TL, Özellik: 1023)
# -> Eklendi: ref_50kr_f.jpg (Değer: 0.5 TL, Özellik: 1180)
# -> Eklendi: ref_25kr_h.jpg (Değer: 0.25 TL, Özellik: 1024)
# -> Eklendi: ref_1tl_c.jpg (Değer: 1.0 TL, Özellik: 1371)
# -> Eklendi: ref_50kr_g.jpg (Değer: 0.5 TL, Özellik: 1103)
# -> Eklendi: ref_25kr_k.jpg (Değer: 0.25 TL, Özellik: 1043)
# -> Eklendi: ref_50kr_b.jpg (Değer: 0.5 TL, Özellik: 705)
# -> Eklendi: ref_25kr_a.jpg (Değer: 0.25 TL, Özellik: 247)
# -> Eklendi: ref_1tl_e.jpg (Değer: 1.0 TL, Özellik: 1136)
# -> Eklendi: ref_5kr_f.jpg (Değer: 0.05 TL, Özellik: 850)
# -> Eklendi: ref_25kr_j.jpg (Değer: 0.25 TL, Özellik: 1038)
# -> Eklendi: ref_1kr_f.jpg (Değer: 0.01 TL, Özellik: 224)
# -> Eklendi: ref_5kr_d.jpg (Değer: 0.05 TL, Özellik: 904)
# -> Eklendi: ref_5kr_g.jpg (Değer: 0.05 TL, Özellik: 558)
# -> Eklendi: ref_10kr_g.jpg (Değer: 0.1 TL, Özellik: 1042)
# -> Eklendi: ref_5kr_b.jpg (Değer: 0.05 TL, Özellik: 353)
# -> Eklendi: ref_25kr_d.jpg (Değer: 0.25 TL, Özellik: 440)
# -> Eklendi: ref_25kr_e.jpg (Değer: 0.25 TL, Özellik: 848)
# -> Eklendi: ref_50kr_h.jpg (Değer: 0.5 TL, Özellik: 884)
# -> Eklendi: ref_50kr_a.jpg (Değer: 0.5 TL, Özellik: 702)
# -> Eklendi: ref_50kr_e.jpg (Değer: 0.5 TL, Özellik: 710)
# -> Eklendi: ref_25kr_l.jpg (Değer: 0.25 TL, Özellik: 820)
# -> Eklendi: ref_10kr_f.jpg (Değer: 0.1 TL, Özellik: 426)
# -> Eklendi: ref_5kr_c.jpg (Değer: 0.05 TL, Özellik: 517)
# -> Eklendi: ref_1tl_a.jpg (Değer: 1.0 TL, Özellik: 1698)
# -> Eklendi: ref_25kr_f.jpg (Değer: 0.25 TL, Özellik: 890)
# -> Eklendi: ref_50kr_d.jpg (Değer: 0.5 TL, Özellik: 488)
# -> Eklendi: ref_10kr_h.jpg (Değer: 0.1 TL, Özellik: 629)
# -> Eklendi: ref_5kr_e.jpg (Değer: 0.05 TL, Özellik: 669)
# -> Eklendi: ref_10kr_i.jpg (Değer: 0.1 TL, Özellik: 427)
# Toplam 52 adet referans şablonu yüklendi.
#
# Resimde 3 adet olası para bulundu. Analiz ediliyor...
# Para #1: 1 Kr tespit edildi. (Referans: ref_1kr_c.jpg, Eşleşme: 155)
# Para #2: 5 Kr tespit edildi. (Referans: ref_5kr_c.jpg, Eşleşme: 452)
# Para #3: 10 Kr tespit edildi. (Referans: ref_10kr_d.jpg, Eşleşme: 437)
#
# --- TOPLAM TUTAR: 0.16 TL ---
# Sonuç Görseli:
# <PIL.Image.Image image mode=RGB size=1200x1600>
